# %%
#Q-Q plot

import numpy as np

#N(0,1) - standard normal distribution
#loc-mean, scale-variance, size
std_normal = np.random.normal(loc=0, scale=1, size=100)

for i in range(0,101):
    print(i, np.percentile(std_normal,i))
# Out:
# 0 -2.179821252547792
# 1 -2.176984225312703
# 2 -2.1635905351226237
# 3 -1.9911097970621197
# 4 -1.711362713653427
# 5 -1.4575058213331968
# 6 -1.430303820164791
# 7 -1.3929260094748612
# 8 -1.3897691585943874
# 9 -1.3879586178624603
# 10 -1.2255816347413817
# 11 -1.1402093410480958
# 12 -1.0966802070204125
# 13 -1.0843515612956276
# 14 -1.0066799629321368
# 15 -0.9341749417499139
# 16 -0.8619316620377827
# 17 -0.8447017990735113
# 18 -0.7520180694169387
# 19 -0.6997701543130358
# 20 -0.6869967502105542
# 21 -0.6590197769027952
# 22 -0.6444385378096114
# 23 -0.6339797621967488
# 24 -0.6089769219556808
# 25 -0.5929218433110958
# 26 -0.5516154054995727
# 27 -0.5160800724782134
# 28 -0.47864612954525565
# 29 -0.45654813780790926
# 30 -0.4304956312938657
# 31 -0.39463094972808843
# 32 -0.3646081805577067
# 33 -0.35035894328402073
# 34 -0.3074552709965375
# 35 -0.2822042771959277
# 36 -0.2778250071824292
# 37 -0.2647145187939453
# 38 -0.2540499055323385
# 39 -0.2409825381546199
# 40 -0.21177397997731376
# 41 -0.19514610022851514
# 42 -0.16634616997575474
# 43 -0.13980786100166237
# 44 -0.12830231194834174
# 45 -0.07910436652831453
# 46 -0.022316665807924217
# 47 0.004412912400401737
# 48 0.03234779224705967
# 49 0.056091442234524495
# 50 0.06650456068361053
# 51 0.07541397369636033
# 52 0.08387843289215219
# 53 0.08931436868306797
# 54 0.10725953829975463
# 55 0.13216992551388532
# 56 0.1406606149059842
# 57 0.18232908894501745
# 58 0.24404449017596735
# 59 0.26162161382278
# 60 0.26410186135000746
# 61 0.2865989894306988
# 62 0.32747224223392324
# 63 0.3466597102152433
# 64 0.36004530354598485
# 65 0.3615681685982036
# 66 0.3643481602711798
# 67 0.3702099160567849
# 68 0.39668456172917765
# 69 0.4505882158094144
# 70 0.4831717353589501
# 71 0.5318392784774093
# 72 0.5392102083358161
# 73 0.5705924714413932
# 74 0.6354030013556369
# 75 0.7318633163270064
# 76 0.799169432275418
# 77 0.840117767550135
# 78 0.8650421618620739
# 79 0.9071476100569266
# 80 0.9397345831451442
# 81 0.9449634076913277
# 82 0.9660341724993987
# 83 1.0005351684582502
# 84 1.0037624944464802
# 85 1.032257575038227
# 86 1.1701495666619015
# 87 1.2226281256597462
# 88 1.229206180242709
# 89 1.2553520206522375
# 90 1.2968107012636143
# 91 1.3444471603412962
# 92 1.4322979017063935
# 93 1.4463350140808655
# 94 1.5090591477487805
# 95 1.6742312376433959
# 96 1.8301618721272053
# 97 1.8727980982696821
# 98 2.1142793430460616
# 99 2.3790016508183935
# 100 2.947837020484152

# %%
import scipy.stats as stats
import pylab
#Generate 100 samples from N(20,5)
measurements = np.random.normal(loc=20, scale=5, size=100)

#probplot-probability plot
stats.probplot(measurements, dist='norm', plot=pylab)
pylab.show()

# %%
measurements = np.random.uniform(low=-1, high=1, size=1000)
stats.probplot(measurements, dist='norm', plot=pylab)
pylab.show()
